"c5997ece-02cc-4afc-9330-ff11e60ac4f3","type":"GlyphRenderer"},{"id":"8ea6764f-46f9-4acb-beb9-21e83cb62a40","type":"GlyphRenderer"},{"id":"c0418ccb-c5bd-4c22-9061-87fac8e3df28","type":"GlyphRenderer"},{"id":"411477f2-d964-4d6f-8fa4-8e996905a1b4","type":"GlyphRenderer"},{"id":"5d75783f-5fb5-4a5e-8085-9502d8f7f7db","type":"GlyphRenderer"},{"id":"49a2ada7-566d-440c-9038-8dbcd97bdb07","type":"GlyphRenderer"},{"id":"46b75533-ec08-4048-a416-9bda90dc422d","type":"GlyphRenderer"},{"id":"d2a373 ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-ba59c660de26> in <module>()
#       1 hist = Histogram(df.dropna(), values="Age", color="Sex", bins=12)
#       2
# ----> 3 show(hist)
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\io.pyc in show(obj, browser, new)
#     302     if obj not in _state.document.roots:
#     303         _state.document.add_root(obj)
# --> 304     return _show_with_state(obj, _state, browser, new)
#     305
#     306
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\io.pyc in _show_with_state(obj, state, browser, new)
#     312
#     313     if state.notebook:
# --> 314         comms_handle = _show_notebook_with_state(obj, state)
#     315         shown = True
#     316
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\io.pyc in _show_notebook_with_state(obj, state)
#     352         comms_target = make_id()
#     353         publish_display_data({'text/html': notebook_div(obj, comms_target)})
# --> 354         handle = _CommsHandle(get_comms(comms_target), state.document, state.document.to_json())
#     355         state.last_comms_handle = handle
#     356         return handle
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\document.pyc in to_json(self)
#     818         # this is a total hack to go via a string, needed because
#     819         # our BokehJSONEncoder goes straight to a string.
# --> 820         doc_json = self.to_json_string()
#     821         return loads(doc_json)
#     822
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\document.pyc in to_json_string(self, indent)
#     811         }
#     812
# --> 813         return serialize_json(json, indent=indent)
#     814
#     815     def to_json(self):
#
# C:\Users\StFed\Anaconda2\lib\site-packages\bokeh\core\json_encoder.pyc in serialize_json(obj, encoder, indent, **kwargs)
#      97         indent = 2
#      98
# ---> 99     return json.dumps(obj, cls=encoder, allow_nan=False, indent=indent, separators=separators, sort_keys=True, **kwargs)
#
# C:\Users\StFed\Anaconda2\lib\json\__init__.pyc in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, encoding, default, sort_keys, **kw)
#     249         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     250         separators=separators, encoding=encoding, default=default,
# --> 251         sort_keys=sort_keys, **kw).encode(obj)
#     252
#     253
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in encode(self, o)
#     207         chunks = self.iterencode(o, _one_shot=True)
#     208         if not isinstance(chunks, (list, tuple)):
# --> 209             chunks = list(chunks)
#     210         return ''.join(chunks)
#     211
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode(o, _current_indent_level)
#     432                 yield chunk
#     433         elif isinstance(o, dict):
# --> 434             for chunk in _iterencode_dict(o, _current_indent_level):
#     435                 yield chunk
#     436         else:
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode_list(lst, _current_indent_level)
#     330                 else:
#     331                     chunks = _iterencode(value, _current_indent_level)
# --> 332                 for chunk in chunks:
#     333                     yield chunk
#     334         if newline_indent is not None:
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     406                 else:
#     407                     chunks = _iterencode(value, _current_indent_level)
# --> 408                 for chunk in chunks:
#     409                     yield chunk
#     410         if newline_indent is not None:
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in _iterencode_dict(dct, _current_indent_level)
#     398                 yield str(value)
#     399             elif isinstance(value, float):
# --> 400                 yield _floatstr(value)
#     401             else:
#     402                 if isinstance(value, (list, tuple)):
#
# C:\Users\StFed\Anaconda2\lib\json\encoder.pyc in floatstr(o, allow_nan, _repr, _inf, _neginf)
#     252                 raise ValueError(
#     253                     "Out of range float values are not JSON compliant: " +
# --> 254                     repr(o))
#     255
#     256             return text
#
# ValueError: Out of range float values are not JSON compliant: nan
