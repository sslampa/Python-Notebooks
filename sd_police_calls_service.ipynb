# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df_2016 = pd.read_csv('data/pd_calls_for_service_2016_datasd.csv')
# Out:
# C:\Users\StFed\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_dispo = pd.read_csv('data/pd_dispo_codes_datasd.csv')

# %%
df_call_type = pd.read_csv('data/pd_cfs_calltypes_datasd.csv')

# %%
df_call_type.head()
# Out:
#   call_type               description
# 0        10   OUT OF SERV, SUBJTOCALL
# 1     10-97           ARRIVE ON SCENE
# 2      1016       PRISONER IN CUSTODY
# 3    1016PT  PTU (PRISONER TRANSPORT)
# 4    1016QC     SHOPLIFTER/QUICK CITE

# %%
df_2016.head()
# Out:
#    incident_num            date_time  day  stno stdir1          street  \
# 0  P16010000001  2016-01-01 00:00:04    6  1400    NaN     CONTINENTAL
# 1  P16010000002  2016-01-01 00:00:06    6     0    NaN  SHOPS INFO LOG
# 2  P16010000003  2016-01-01 00:00:20    6     0    NaN    CHP INFO LOG
# 3  P16010000004  2016-01-01 00:00:25    6     0    NaN  FRONT COUNTERS
# 4  P16010000006  2016-01-01 00:00:33    6   500    NaN          SICARD
#
#   streettype stdir2 stname2 sttype2 call_type disposition   beat  priority
# 0         ST    NaN     NaN     NaN      459A           K  713.0       2.0
# 1        NaN    NaN     NaN     NaN     SHOPS           K  999.0       4.0
# 2        NaN    NaN     NaN     NaN   INFOCHP           K  999.0       4.0
# 3        NaN    NaN     NaN     NaN        FC           K  999.0       4.0
# 4         ST    NaN     NaN     NaN       AU2           W  512.0       2.0

# %%
pd.DataFrame(df_2016.disposition.value_counts().head(13)).merge(df_dispo, left_index=True, right_on='dispo_code', how='left')
# Out:
#     disposition dispo_code                                        description
# 2        212417          K                                 NO REPORT REQUIRED
# 7        102635          O                                              OTHER
# 1         34281          R                                             REPORT
# 3         25831          W  NO DISPATCH OR INCIDENT CANCELLED PRIOR TO DIS...
# 9         24314        CAN                                             CANCEL
# 0         18711          A                                             ARREST
# 5         14257          U                                          UNFOUNDED
# 10         7684        DUP                   DUPLICATE CALL, CROSS REFERENCED
# 24         6503         OT                                  TRANSIENT RELATED
# 22         2870         KT         NO FURTHER ACTION TAKEN, TRANSIENT RELATED
# 6          2712          S                STOLEN VEHICLE OR RECOVERED VEHICLE
# ...

# %%
pd.DataFrame(df_2016.call_type.value_counts().head(50)).merge(df_call_type, left_index=True, right_on='call_type', how='left').drop('call_type_y', axis=1)
# Out:
#     call_type  call_type_x                     description
# 35       1150        38159        TRAFFIC STOP/WITHLICENSE
# 99        415        36431                DISTURBING PEACE
# 117      459A        26654                  BURGLARY ALARM
# 36       1151        20246        PED STOP/FIELD INTERVIEW
# 217        CW        16385               CHECK THE WELFARE
# 107      415V        12813     DISTURBING PEACE W/VIOLENCE
# 141       586        12392                 ILLEGAL PARKING
# 157       911        10689     UNK EMERG,HANG UP/OPEN LINE
# 2        1016         9519             PRISONER IN CUSTODY
# 102      415N         8608     DISTURBING PEACE NOISE ONLY
# 230        FD         8307       FLAG DOWN/FIELD INITIATED
# 53       1185         7821           REQUEST FOR TOW TRUCK
# 50       1183         7695              NO DETAIL ACCIDENT
# 54       1186         7414                  SPECIAL DETAIL
# 238        FU         7156         FOLLOW-UP BY FIELD UNIT
# ...
